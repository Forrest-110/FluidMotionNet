# %%
from lattice import Lattice
import torch
import numpy as np
l=Lattice(nb=8,spacing=10,batchsize=1)
pc=(torch.rand((1,2000,2))*np.pi*2).cuda()
flow=pc[:,:,1].view(1,2000,1)
l.splat(flow,pc)

l.visualize()
# Out:
# torch.Size([1, 2000, 8, 1]) torch.Size([1, 100, 8, 1])
# torch.Size([1, 100, 2]) torch.Size([1, 100, 1])
